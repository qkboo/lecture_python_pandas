# %% [markdown]
# day4 과제는 아래 1, 2번 중 하나를 골라서 하신후 쥬피터 노트북 파일 'day4_이름.ipynb' 형식으로 제출하세요.
#  - gangtai.goh@gmail.com

# %% [markdown]
# # 1 과제:
#
# 교재 연습문제 `p257~259` 의 문제 `1~6`번을 쥬피터 노트북으로 작성해 제출

# %% [markdown]
# # 2과제
#
# 링크의 문제를 읽고 쥬피터 노트북으로 작성해 제출하시오.
#  - jungol2857
#  - http://www.jungol.co.kr/bbs/board.php?bo_table=pbank&wr_id=2119&sca=2050

# %% [markdown]
# ![image.png](attachment:63e0a453-5f86-4a89-899c-0aa3fafcc274.png)
